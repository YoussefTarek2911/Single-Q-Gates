# %%
import numpy as np
from qiskit import QuantumCircuit, transpile, Aer, execute
from qiskit.visualization import *
from qiskit.quantum_info import Statevector

# %%
backend = Aer.get_backend('statevector_simulator')

# %%
qc1 = QuantumCircuit(4)
qc1.x(0)
qc1.y(1)
qc1.z(2)
qc1.s(3)

qc1.draw(output='mpl')

# %%
out1 = execute(qc1, backend).result().get_statevector()
aux = Statevector(out1,2**4)
aux.draw('latex')
# Out:
# $$i |0011\rangle$$

# %%
plot_bloch_multivector(out1)

# %%
qc2 = QuantumCircuit(4)
qc2.x(range(4))
qc2.x(0)
qc2.y(1)
qc2.z(2)
qc2.s(3)

qc2.draw(output='mpl')

# %%
out2 = execute(qc2,backend).result().get_statevector()
aux = Statevector(qc2)
aux.draw('latex')
# Out:
# $$- |1100\rangle$$

# %%
plot_bloch_multivector(out2)

# %%
qc3 = QuantumCircuit(4)
qc3.h(range(4))
qc3.x(0)
qc3.y(1)
qc3.z(2)
qc3.s(3)

qc3.draw(output='mpl')

# %%
out3 = execute(qc3,backend).result().get_statevector()
aux = Statevector(out3,2**4)
aux.draw('latex')
# Out:
# $$- \frac{i}{4} |0000\rangle- \frac{i}{4} |0001\rangle+\frac{i}{4} |0010\rangle+\frac{i}{4} |0011\rangle+\frac{i}{4} |0100\rangle+\frac{i}{4} |0101\rangle + \ldots - \frac{1}{4} |1011\rangle- \frac{1}{4} |1100\rangle- \frac{1}{4} |1101\rangle+\frac{1}{4} |1110\rangle+\frac{1}{4} |1111\rangle$$

# %%
plot_bloch_multivector(out3)

# %%
qc4 = QuantumCircuit(4)
qc4.x(range(4))
qc4.h(range(4))
qc4.x(0)
qc4.y(1)
qc4.z(2)
qc4.s(3)

qc4.draw(output='mpl')

# %%
out4 = execute(qc4,backend).result().get_statevector()
plot_bloch_multivector(out4)

# %%
qc5 = QuantumCircuit(4)
qc5.h(range(4))
qc5.s(range(4))
qc5.x(0)
qc5.y(1)
qc5.z(2)
qc5.s(3)

qc5.draw(output='mpl')

# %%
out5 = execute(qc5,backend).result().get_statevector()
plot_bloch_multivector(out5)

# %%
qc6 = QuantumCircuit(4)
qc6.x(range(4))
qc6.h(range(4))
qc6.s(range(4))
qc6.x(0)
qc6.y(1)
qc6.z(2)
qc6.s(3)
qc6.draw(output='mpl')

# %%
out6 = execute(qc6,backend).result().get_statevector()
plot_bloch_multivector(out6)
